# %% [markdown]
# # Distribution

# %% [markdown]
# ### Distribution

# %%
# %matplotlib inline
from __future__ import division      
import numpy as np
import scipy.stats as stats     # for pdfs 
import matplotlib.pyplot as plt
import numpy.random as random
import matplotlib.mlab as MLA

# %% [markdown]
# ## Sampling

# %% [markdown]
# ![](http://www.statsmodels.org/stable/_static/statsmodels_hybi_banner.png)
# ![](http://www.wizdomhub.com/wp-content/uploads/2017/08/numpy_project_page.jpg)

# %% [markdown]
# ![](http://ipython.readthedocs.io/en/stable/_images/ipy_013_qtconsole_completer.png)

# %% [markdown]
# ### `random.uniform`

# %%
s = np.random.uniform(0,1,1200)
count, bins, ignored = plt.hist(s, 12, normed=True)  
plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')  
plt.show();

# %% [markdown]
# ### `normal`

# %%
mu, sigma = 10, 10  
x = mu + sigma*np.random.randn(5000)  
# the histogram of the data and add a 'best fit' line 
n, bins, patches = plt.hist(x, 20, normed=1, facecolor='blue', alpha=0.8)   
y = MLA.normpdf( bins, mu, sigma)  
l = plt.plot(bins, y, 'g--', linewidth=3)  
plt.xlabel('samples');plt.ylabel('p')  
plt.title(r'$Normal\ pdf\ m=10,\ \sigma=10$')  
plt.axis([-30, 50, 0, 0.042])  
plt.show();

# %% [markdown]
# ### Distributions

# %% [markdown]
# possion: $$P(x,\lambda)=\frac{\lambda^{n}e^{-\lambda }}{n!}$$
#
# expotential: $$f(x)=\lambda e^{-\lambda x}$$
#
# Normal distribution:
# $$f(x)=\frac{1}{\sigma\sqrt{2\pi}}e^{\frac{-(x-\mu)^2}{2\sigma}}$$

# %% [markdown]
# ### Distributions

# %%
# hist a set of random numbers, Gaussian distributed
fig=plt.figure(figsize=(15, 10))

ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

N = 1000000

x = np.random.poisson(5, N)
ax1.hist(x, 100, normed=True, color='#348ABD', alpha=0.4)

x = np.random.randn(N)
ax2.hist(x ,100, normed=True, color='#348ABD', alpha=0.4);

x = np.random.uniform(0,1,N)
ax3.hist(x ,100, normed=True, color='#348ABD', alpha=0.4);


x = np.random.exponential(1/250,N)
ax4.hist(x, normed=True,bins=200,color='#348ABD',alpha=0.4)
#ax4.plot([0,max(Y)],[target,target],'r--')
#ax4.ylim(0,target*1.1)

plt.suptitle("Histogram of random drawn",fontsize=20);

# %% [markdown]
# ### Normal distribution

# %% [markdown]
# - Normal distribution(probability density function):
# $$f(x)=\frac{1}{\sigma\sqrt{2\pi}}e^{\frac{-(x-\mu)^2}{2\sigma}}$$

# %% [markdown]
# - standard normal distribution: $$f(x)=\frac{1}{\sqrt{2\pi}}e^{\frac{-x^2}{2}}$$

# %% [markdown]
# ## Standard Normal Distribution Ⅰ

# %%
x = np.linspace(-4,4, 64)
y = (1/(np.sqrt(2*np.pi)))*np.exp(-((x**2)/(2)))


plt.plot(x,y,'-', color='red')
plt.title('Standard Normal Distribution',fontsize=15)
plt.xlabel('x',fontsize=15)
plt.ylabel('Probability density',fontsize=15);

# %% [markdown]
# ## Standard Normal Distribution Ⅱ

# %%
x = np.linspace(-4,4, 64)
y = stats.norm.pdf(x)
plt.plot(x,y,'-', color='#A60628')
plt.title('Standard Normal Distribution',fontsize=15)
plt.xlabel('x',fontsize=15)
plt.ylabel('Probability density',fontsize=15);

# %% [markdown]
# ## Normal Distribution Ⅰ

# %%
u = 5 # mean
s = 1 # standard deviation
x = np.linspace(0,10, 64)
y = (1/(np.sqrt(2*np.pi*s*s)))*np.exp(-(((x-u)**2)/(2*s*s)))

plt.plot(x,y,'o-', color='#A60628')
plt.title('Gaussian: $\mu$=%.1f, $\sigma$=%.1f' % (u,s),fontsize=15)
plt.xlabel('x',fontsize=15)
plt.ylabel('Probability density',fontsize=15);

# %% [markdown]
# ## Normal distribution Ⅱ

# %%
from scipy.stats import norm
u = 5 # mean
s = 1 # standard deviation
x = np.linspace(0,10, 64)
y = stats.norm.pdf(x,u,s)

plt.plot(x,y,'-', color='#A60628')
plt.title('Gaussian: $\mu$=%.1f, $\sigma$=%.1f' % (u,s),fontsize=15)
plt.xlabel('x',fontsize=15)
plt.ylabel('Probability density',fontsize=15);

# %%
from scipy.stats import norm
u = 5 # mean
s = 1 # standard deviation
x = np.linspace(0,10, 64)
y = stats.norm.cdf(x,u,s)

plt.plot(x,y,'-', color='#A60628')
plt.title('Gaussian: $\mu$=%.1f, $\sigma$=%.1f' % (u,s),fontsize=15)
plt.xlabel('x',fontsize=15)
plt.ylabel('Probability density',fontsize=15);

# %%
N = 100
p = 0.5
n = np.arange(0, 100)
y = stats.binom.pmf(n, N, p)

plt.plot(n,y,'o-', color='#348ABD')
plt.title('Binomial: N=%i , p=%.2f' % (N,p),fontsize=15)
plt.xlabel('x',fontsize=15)
plt.ylabel('Probability density',fontsize=15);

# %%
u=20
n=range(10, 30)
y=stats.poisson.pmf(n,u)

plt.plot(n,y,'-', color='#348ABD')
plt.title('Poisson: $\mu$ =%i' % u,fontsize=15)
plt.xlabel('x',fontsize=15)
plt.ylabel('Probability density',fontsize=15);

# %% [markdown]
# ### Central limit theorem

# %% [markdown]
# ![](https://d32ogoqmya1dw8.cloudfront.net/images/introgeo/teachingwdata/CntrlLt100.jpg)

# %% [markdown]
# ### Central limit theorem: normal

# %%
f = plt.figure(figsize=(18, 10))
 
def plotHist(nr, N, n_, mean, var0, x0):
    ''' plots the RVs'''
    x = np.zeros((N))
    sp = f.add_subplot(2, 2, n_ )
    
    for i in range(N):    
        for j in range(nr):
            x[i] += np.random.randn() 
        x[i] *= 1/nr
    plt.hist(x, 100, normed=True, color='#348ABD', label=" %d RVs"%(nr));
    plt.setp(sp.get_yticklabels(), visible=False)
    
    variance = var0/nr                     
    fac = 1/np.sqrt(2*np.pi*variance)
    dist = fac*np.exp(-(x0-mean)**2/(2*variance))
    plt.plot(x0,dist,color='#A60628',linewidth=3,label='CLT',alpha=0.8)
    plt.xlabel('r')
    plt.xlim([-3, 3])
    leg = plt.legend(loc="upper right")
    leg.get_frame().set_alpha(0.1)

    
N = 10000 # number of samples taken
nr = ([1, 2, 4, 10])

mean, var0 = 0, 1 # mean and variance of exponential distribution
x0 = np.linspace(-3, 3, 128)

for i in range(np.size(nr)):
    plotHist(nr[i], N, i+1, mean, var0, x0)

plt.suptitle("Addition of independent Gaussian distributions is a Gaussian distribution",fontsize=20);

# %% [markdown]
# ### Central limit theorem: uniform

# %%
f = plt.figure(figsize=(18, 10))
 
def plotHist(nr, N, n_, mean, var0, x0):
    ''' plots the RVs'''
    x = np.zeros((N))
    sp = f.add_subplot(3, 2, n_ )
    
    for i in range(N):    
        for j in range(nr):
            x[i] += np.random.random() 
        x[i] *= 1/nr
    plt.hist(x, 100, normed=True, color='#348ABD', label=" %d RVs"%(nr));
    plt.setp(sp.get_yticklabels(), visible=False)
    
    variance = var0/nr                     
    fac = 1/np.sqrt(2*np.pi*variance)
    dist = fac*np.exp(-(x0-mean)**2/(2*variance))
    plt.plot(x0,dist,color='#A60628',linewidth=3,label='CLT',alpha=0.8)
    plt.xlabel('r')
    plt.xlim([0, 1])
    leg = plt.legend(loc="upper left")
    leg.get_frame().set_alpha(0.1)

    
N = 10000  # number of samples taken
nr = ([1, 4, 16, 32, 128,512])

mean, var0 = 0.5, 1.0/12  # mean and variance of uniform distribution in range 0, 1
x0 = np.linspace(0, 1, 128)

for i in range(np.size(nr)):
    plotHist(nr[i], N, i+1, mean, var0, x0)

plt.suptitle("Addition of uniform random variables (RVs) converge to a Gaussian distribution (CLT)",fontsize=20);

plt.show()

# %% [markdown]
# ### Central limit theorem: expotential

# %%
f = plt.figure(figsize=(18, 10))
 
def plotHist(nr, N, n_, mean, var0, x0):
    ''' plots the RVs'''
    x = np.zeros((N))
    sp = f.add_subplot(3, 2, n_ )
    
    for i in range(N):    
        for j in range(nr):
            x[i] += np.random.exponential(mean) 
        x[i] *= 1/nr
    plt.hist(x, 100, normed=True, color='#348ABD', label=" %d RVs"%(nr));
    plt.setp(sp.get_yticklabels(), visible=False)
    
    variance = var0/nr                     
    fac = 1/np.sqrt(2*np.pi*variance)
    dist = fac*np.exp(-(x0-mean)**2/(2*variance))
    plt.plot(x0,dist,color='#A60628',linewidth=3,label='CLT',alpha=0.8)
    plt.xlabel('r')
    plt.xlim([0, 1])
    leg = plt.legend(loc="upper right")
    leg.get_frame().set_alpha(0.1)

    
N = 10000   # number of samples taken
nr = ([1, 2, 8, 32, 64, 128])

mean, var0 = 0.5, 0.5*0.5  # mean and variance of exponential distribution
x0 = np.linspace(0, 1, 128)

for i in range(np.size(nr)):
    plotHist(nr[i], N, i+1, mean, var0, x0)

plt.suptitle("Addition of exponential distributed RVs converge to a Gaussian distribution, albeit slowly",fontsize=20);

# %% [markdown]
# ### Discrete distribution

# %% [markdown]
# ![](figures/discrete.png)

# %% [markdown]
# ### Continous distribution

# %% [markdown]
# ![](figures/continuous.png)
